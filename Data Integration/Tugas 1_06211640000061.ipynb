# %%
import pandas as pd
import numpy as np

# %%
data1=pd.read_csv('tugas1.csv')
data2=pd.read_csv('tugas2.csv')
data3=pd.read_csv('tugas3.csv')
data4=pd.read_csv('tugas4.csv')

# %%
hasil1 = pd.merge(data1,data2, on='StdOrder')
hasil1
# Out:
#     StdOrder  RunOrder  CenterPt  Blocks  Material  InjPress  InjTemp  \
# 0          1        65         1       1  Formula1        75       85
# 1          2        56         1       1  Formula2        75       85
# 2          3        13         1       1  Formula1       150       85
# 3          4        93         1       1  Formula2       150       85
# 4          5         7         1       1  Formula1        75      100
# 5          6        66         1       1  Formula2        75      100
# 6          7        60         1       1  Formula1       150      100
# 7          8        14         1       1  Formula2       150      100
# 8          9        88         1       1  Formula1        75       85
# 9         10        35         1       1  Formula2        75       85
# 10        11        55         1       1  Formula1       150       85
# 11        12        72         1       1  Formula2       150       85
# ...

# %%
hasil2 = pd.concat([data3, data4])
hasil2
# Out:
#     StdOrder  RunOrder  CenterPt  Blocks  Material  InjPress  InjTemp  \
# 0          1        65         1       1  Formula1        75       85
# 1          2        56         1       1  Formula2        75       85
# 2          3        13         1       1  Formula1       150       85
# 3          4        93         1       1  Formula2       150       85
# 4          5         7         1       1  Formula1        75      100
# 5          6        66         1       1  Formula2        75      100
# 6          7        60         1       1  Formula1       150      100
# 7          8        14         1       1  Formula2       150      100
# 8          9        88         1       1  Formula1        75       85
# 9         10        35         1       1  Formula2        75       85
# 10        11        55         1       1  Formula1       150       85
# 11        12        72         1       1  Formula2       150       85
# ...
